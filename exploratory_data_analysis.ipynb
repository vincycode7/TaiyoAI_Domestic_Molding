# %% [markdown]
# ## Domestic Market (Contract) Blow Molding, Low Modeling and Analysis

# %% [markdown]
# #### Import Classes

# %%
from configs.configs import get_data_preprocessor_config, get_data_postprocessor_config
from data.data_preprocessing import DataPreProcessor, DataPostProcessor
data_preprocessor_config = get_data_preprocessor_config()
data_postprocessor_config = get_data_postprocessor_config()

# %% [markdown]
# #### Preprocess Data

# %%
#define args
processor = DataPreProcessor(**data_preprocessor_config)
processor.pre_process_data(**data_preprocessor_config)

# %%
import pandas as pd
pd.read_csv("artifacts/data/raw/data.csv").shape
# Out:
# (276, 50)

# %%
processor.transformed_X_data.shape
# Out:
# (276, 46)

# %%
processor.transformed_X_data_norm.head()
# Out:
#    south_africa_export  pcu32611132611115  australia__export  \
# 0             0.002676       7.924834e-08           0.000099
# 1             0.002725       7.992006e-08          -0.000004
# 2             0.002770       8.217764e-08          -0.000219
# 3             0.002632       7.911167e-08           0.000180
# 4             0.002674       8.177181e-08           0.000300
#
#    domestic_market_contract_blow_molding_low  japan_import  \
# 0                               4.483524e-08      0.019868
# 1                               4.514815e-08      0.020138
# 2                               5.021483e-08      0.020616
# 3                               5.113503e-08      0.019772
# 4                               5.245348e-08      0.020378
#
#    producer_price_index_by_industry_plastics_material_and_resins_manufacturing_thermoplastic_resins_and_plastics_materials  \
# 0                                       1.524398e-07
# 1                                       1.560364e-07
# 2                                       1.632540e-07
# 3                                       1.647201e-07
# 4                                       1.736545e-07
#
#           expch       gasregm  pcu325211325211    brazil  ...  \
# 0  9.438365e-07  1.409576e-09     1.731078e-07  0.011321  ...
# 1  1.071112e-06  1.516317e-09     1.756373e-07  0.009739  ...
# 2  1.484685e-06  1.691682e-09     1.821125e-07  0.015724  ...
# 3  1.335495e-06  1.593890e-09     1.787550e-07  0.015338  ...
# 4  1.703399e-06  1.659539e-09     1.869353e-07  0.018708  ...
#
#    pcu32611332611301  turkey_import       mhhngsp  wpu0915021625  usa_import  \
# 0       1.162436e-07       0.007472  2.646373e-09   6.340947e-08    0.136661
# 1       1.162840e-07       0.006219  2.929124e-09   6.393445e-08    0.137626
# 2       1.183954e-07       0.007500  3.113320e-09   6.565679e-08    0.140377
# 3       1.163050e-07       0.007800  3.307457e-09   6.307832e-08    0.136193
# 4       1.186341e-07       0.011681  4.006553e-09   6.522741e-08    0.138659
#
#    india_export  saudi_import       wtisplc  france_export  france_import
# 0      0.026692      0.006169  2.972249e-08       0.032071       0.038536
# 1      0.024461      0.006359  3.231947e-08       0.036896       0.040432
# 2      0.025245      0.006524  3.335381e-08       0.039910       0.050376
# 3      0.028814      0.006034  2.800459e-08       0.026887       0.035077
# 4      0.026781      0.006370  3.211939e-08       0.031710       0.032757
#
# [5 rows x 46 columns]

# %%
processor.transformed_Y_data.head()
# Out:
#    target_shift  target_shift_direction  target_shift_direction_-1  \
# 0          41.0                       1                        0.0
# 1          45.0                       1                        0.0
# 2          47.0                       1                        0.0
# 3          47.0                       1                        0.0
# 4          47.0                       1                        0.0
#
#    target_shift_direction_1
# 0                       1.0
# 1                       1.0
# 2                       1.0
# 3                       1.0
# 4                       1.0

# %% [markdown]
# #### Postprocess Data

# %%
#define args
processor = DataPostProcessor(**data_postprocessor_config)
processor.post_process_data(**data_postprocessor_config)
# Out:
# {'split_percentage': 0.2, 'split_data': True, 'process_data': True, 'save_datapipelined': True, 'transform_data': True, 'save_transformed': True, 'save_transformed_path': None, 'data_file_path': 'artifacts/data/raw/data.csv', 'left_split_save_path': 'train_split.csv', 'right_split_save_path': 'test_split.csv', 'save_split': False, 'ignore_target_pipeline': False}

# %%
processor.transformed_X_data
# Out:
#      australia__export  france_import  united_kingdome_export  saudi_import  \
# 0        536608.259510   3.523992e+07            2.873192e+07  6.535772e+06
# 1        441833.066186   3.671675e+07            2.953081e+07  6.545688e+06
# 2        346731.421936   4.514456e+07            3.167147e+07  6.560068e+06
# 3        618432.271679   3.224035e+07            2.752401e+07  6.528995e+06
# 4        627434.107742   2.935163e+07            2.721160e+07  6.543129e+06
# ..                 ...            ...                     ...           ...
# 271     -714314.210161   6.076678e+07            3.200051e+07  6.504079e+06
# 272     -225842.147630   8.326923e+07            4.368041e+07  6.488476e+06
# 273     -802637.713301   8.299223e+07            4.546880e+07  6.501399e+06
# 274      675283.577243   5.866789e+07            3.578645e+07  6.576128e+06
# 275      605002.949163   6.083883e+07            3.647792e+07  6.594092e+06
#
#      canada_export  wpu0915021625  gasregm  united_kingdome_import  \
# 0     1.100263e+08      56.168722    1.289            4.862112e+07
# 1     1.093996e+08      55.839162    1.377            4.996477e+07
# 2     1.135559e+08      56.320877    1.516            5.215729e+07
# 3     1.111391e+08      57.036649    1.465            4.722976e+07
# 4     1.095929e+08      57.003813    1.487            4.980568e+07
# ..             ...            ...      ...                     ...
# 271   1.230656e+08     143.702000    3.975            8.187255e+07
# 272   1.282251e+08     143.787000    3.700            7.447744e+07
# 273   1.294932e+08     143.472000    3.815            1.094211e+08
# 274   1.149740e+08     142.166000    3.685            6.008673e+07
# 275   1.189501e+08     123.551326    3.210            6.262054e+07
#
#      wpu072205011  china_export  ...  saudi_export  india_export  \
# 0       58.003555  1.215966e+07  ...  3.887997e+08  3.033988e+07
# 1       59.679533  1.268778e+07  ...  3.856975e+08  2.811088e+07
# 2       61.233659  1.393975e+07  ...  3.833664e+08  2.699872e+07
# 3       59.570888  1.155622e+07  ...  3.912062e+08  3.249341e+07
# 4       63.440812  1.154814e+07  ...  3.883679e+08  3.031327e+07
# ..            ...           ...  ...           ...           ...
# 271    135.466000  2.669989e+07  ...  4.103966e+08  5.476717e+06
# 272    137.316000  2.381510e+07  ...  4.117570e+08  2.561873e+06
# 273    138.090000  2.601635e+07  ...  4.073089e+08  5.651870e+06
# 274    137.637000  1.579173e+07  ...  3.873877e+08  2.308840e+07
# 275    137.790000  1.670027e+07  ...  3.859064e+08  2.157931e+07
#
#      russia_export  japan_import   wpufd4111    usa_export  \
# 0     3.380458e+07  1.851504e+07  135.000000  3.348994e+08
# 1     3.574029e+07  1.856617e+07  136.000000  3.373902e+08
# 2     3.318018e+07  1.879530e+07  136.000000  3.346735e+08
# 3     3.094182e+07  1.852876e+07  137.300000  3.333555e+08
# 4     2.996452e+07  1.846055e+07  138.200000  3.228117e+08
# ..             ...           ...         ...           ...
# 271   5.860261e+07  2.609701e+07  262.981000  4.531227e+08
# 272   5.604090e+07  2.127734e+07  265.656000  4.017906e+08
# 273   5.884897e+07  1.918209e+07  268.312000  4.033951e+08
# 274   3.250459e+07  1.751404e+07  278.025000  2.856840e+08
# 275   2.893594e+07  1.772329e+07  223.996779  2.794786e+08
#
#      producer_price_index_by_industry_plastics_material_and_resins_manufacturing_thermoplastic_resins_and_plastics_materials  \
# 0                                              139.400
# 1                                              141.700
# 2                                              146.300
# 3                                              151.400
# 4                                              155.600
# ..                                                 ...
# 271                                            329.278
# 272                                            326.451
# 273                                            316.901
# 274                                            300.185
# 275                                            291.825
#
#      mcoilbrenteu        brazil  pcu32611132611112
# 0           25.51  1.035253e+07          75.490553
# 1           27.78  8.844172e+06          75.914752
# 2           27.49  1.409121e+07          76.687632
# 3           22.76  1.409752e+07          77.021266
# 4           27.74  1.676300e+07          78.132442
# ..            ...           ...                ...
# 271        100.45  2.387014e+07         161.653000
# 272         89.76  2.131733e+07         161.280000
# 273         93.33  1.974837e+07         157.362000
# 274         91.42  1.959579e+07         151.405000
# 275         80.92  3.148330e+07         151.405000
#
# [276 rows x 46 columns]

# %%
processor.transformed_Y_data
# Out:
#      target_shift  target_shift_direction  target_shift_direction_-1  \
# 0       41.000000                       1                        0.0
# 1       45.000000                       1                        0.0
# 2       47.000000                       1                        0.0
# 3       47.000000                       1                        0.0
# 4       47.000000                       1                        0.0
# ..            ...                     ...                        ...
# 271     90.000000                      -1                        1.0
# 272     90.000000                       1                        0.0
# 273     90.000000                       1                        0.0
# 274     90.000000                       1                        0.0
# 275     72.490909                      -1                        1.0
#
#      target_shift_direction_1
# 0                         1.0
# 1                         1.0
# 2                         1.0
# 3                         1.0
# 4                         1.0
# ..                        ...
# 271                       0.0
# 272                       1.0
# 273                       1.0
# 274                       1.0
# 275                       0.0
#
# [276 rows x 4 columns]

# %% [markdown]
# #### Initialize Global Result Table

# %% [markdown]
# #### Train Multi Model (Using various supported model backbones) with T+1

# %% [markdown]
# #### Save T+1 Train Result

# %% [markdown]
# #### Add T+1 Train Result To Global Result Table

# %% [markdown]
# #### Train Multi Model (Using various supported model backbones) with T+2

# %% [markdown]
# #### Save T+2 Train Result

# %% [markdown]
# #### Add T+2 Train Result To Global Result Table

# %% [markdown]
# #### Train Multi Model (Using various supported model backbones) with T+3

# %% [markdown]
# #### Save T+3 Train Result

# %% [markdown]
# #### Add T+3 Train Result To Global Result Table

# %% [markdown]
# #### Data Correlation Visualization

# %% [markdown]
# #### Save Data Correlation Visualization

# %% [markdown]
# #### Select new features based on correlation visualisation

# %% [markdown]
# #### Conduct train for all time steps with the new features based on the correlation

# %% [markdown]
# #### Compare results before correlation and after correlation
